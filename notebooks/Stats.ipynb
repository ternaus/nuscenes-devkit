# %%
import pandas as pd

# %%
import json

# %%
import numpy as np

# %%
with open("/home/vladimir/workspace/data2/lyft/kaggle/train_data/sample_annotation.json") as f:
    df = pd.DataFrame(json.load(f))

# %%
df.head()
# Out:
#                                                token  num_lidar_pts  \
# 0  92bff46db1dbfc9679edc8091770c4256ac3c027e9f0a9...             -1
# 1  04c4c9883de582c5c4e7a45273a978a52b0432de18883f...             -1
# 2  4226ce1636193ced735e21ff3c6dcc292415c72d0f84b4...             -1
# 3  f2446d4ca4b3e79e982cf0a4134af12e71e7b59df42f42...             -1
# 4  1f5bdec4a1dff45dbbb4db094445dd4051eb39c9b4a2a3...             -1
#
#                     size                                       sample_token  \
# 0  [2.064, 5.488, 2.053]  db8b47bd4ebdf3b3fb21598bb41bd8853d12f8d2ef25ce...
# 1  [1.635, 4.339, 1.515]  edf37c1fb1024ba0c1f53ebbf10b6797f781199a9f0e4e...
# 2  [1.963, 4.345, 1.749]  1841b7895e7163a2c1be87e8c1740e759a910cd59157b8...
# 3     [2.2, 5.39, 2.187]  a970c764e7abd7ebc2cc4599a6e3ae58c9773ea3c9cf1d...
# 4  [1.837, 5.406, 1.721]  b909de93ba19460eeea58074ccc1ef6bb302435f37b48c...
#
#                                           rotation  \
# ...

# %%
with open("/home/vladimir/workspace/data2/lyft/kaggle/train_data/sample.json") as f:
    df_sample = pd.DataFrame(json.load(f))

# %%
df_sample.head()
# Out:
#                                                 next  \
# 0  1d2350b3b20e3a5db2407e4075fc14f9f9ddfe0018f1da...
# 1  4f027d171715d57cd62079924e439f9ab17d228f27999a...
# 2  b66fb3c9a787cae35330b69f06cc18a7f06d0e61c7d06f...
# 3  063ea8386aa8156c1cd7c91bb1ac433f0b58d471e12658...
# 4  163666a4128b13159abd8ba202d9f0b05229507c27fc6b...
#
#                                                 prev  \
# 0  14511199ea101b40683cefafb9fcf5c2fb512fa500c3e6...
# 1  692caabc1f06aeda9f43d6252a070178430dec2158f19e...
# 2  0999dad89d3c95dd2976b4631b6deb3b3000e4de27afa3...
# 3  3222c742893edd007b982e9e7db40b7a598972d07bf759...
# 4
#
#                                                token     timestamp  \
# 0  b98a05255ba2632e957884758cb31f0e6fcc8d3cd6ee76...  1.552084e+15
# 1  78ce15b2b7360b8cd696d1097c60ec2184b69c17412564...  1.557855e+15
# 2  095d5bb88eb9cdd223b90d2a1475c0cf2f4b4c2a8aca82...  1.548780e+15
# 3  c2f0b2b2c0d576d42eab6e8703c4eacd302a79d4d702bd...  1.549481e+15
# ...

# %%
with open("/home/vladimir/workspace/data2/lyft/kaggle/train_data/sample_data.json") as f:
    df_data = pd.DataFrame(json.load(f))

# %%
df_data.head()
# Out:
#    is_key_frame                                               prev fileformat  \
# 0          True  d190078ec7869ad5c9e5417371aa3b45eb1c22804a0a29...        bin
# 1          True  83f6f61cb6f2fc9b985cc23bd5613219eee7da390cd083...        bin
# 2          True  44555daed204fea486ec10ea1747432501b9f06fe93041...       jpeg
# 3          True  de75f3f347742035f2442f4a5fa0334946642daa2d07d8...       jpeg
# 4          True  a208568472ef6719faa2540622ada30b004583de9153f4...       jpeg
#
#                                                token     timestamp  \
# 0  ad87e1763749cc8562cca68e2046db128185c80c3e7599...  1.549921e+15
# 1  ea079138d89f3887b2bfcddfe16b747e2ec7a366ce66b3...  1.551742e+15
# 2  454c65ee6c297d64b17852b4c56def9781a84dcb8558a8...  1.550705e+15
# 3  779018e1f92debcf5c5c28e9577677c6595679780bdf9b...  1.546901e+15
# 4  d966960819eb0aca2883cd3c8d8c5e2540bda952a8cada...  1.549650e+15
#
#                                                 next  \
# ...

# %%
with open("/home/vladimir/workspace/data2/lyft/kaggle/train_data/attribute.json") as f:
    df_attribute = pd.DataFrame(json.load(f))

# %%
df_attribute.head()
# Out:
#   description                                              token  \
# 0              f5081f1e5aa941f9d9f727ad186c8db67b916336f975a2...
# 1              1b388c1f5e5149ae173ad3d674e7ad7f1847e213173d14...
# 2              17d61007ee69782e0ad8ffa5f8cd4c075f18b4b09e11f0...
# 3              5466ded30df08d7d825412ac907017d6ae00ff19051c63...
# 4              8b08df37edc70b7327d54b3fbf9e7e5894e1a31a93fe77...
#
#                               name
# 0  object_action_lane_change_right
# 1            object_action_running
# 2   object_action_lane_change_left
# 3             object_action_parked
# 4           object_action_standing

# %%
with open("/home/vladimir/workspace/data2/lyft/kaggle/train_data/calibrated_sensor.json") as f:
    df_calibrated_sensor = pd.DataFrame(json.load(f))

# %%
df_calibrated_sensor.head()
# Out:
#                                         sensor_token  \
# 0  c84592e22beb2c0f14d5159245ce8d6678431b879e940e...
# 1  eb9e8f60a3d6e3328d7512b9f8e6800127fe91f4d62bc8...
# 2  f7dad6bb70cb8e6245f96e5537e382848335872e6e2592...
# 3  286718e1fbc8c8f0ca441969d91c36a8a809666e049e54...
# 4  f7dad6bb70cb8e6245f96e5537e382848335872e6e2592...
#
#                                             rotation  \
# 0  [-0.6784803059109364, 0.6875255645268346, 0.19...
# 1  [0.5048435722738135, -0.4988633710749635, 0.49...
# 2  [0.6837255817101214, -0.6842216370132779, 0.17...
# 3  [0.5296938708729468, -0.4724561819772816, 0.46...
# 4  [0.6850555759619519, -0.6810775131317202, 0.17...
#
#                                     camera_intrinsic  \
# 0  [[882.42699274, 0, 602.047851885], [0.0, 882.4...
# 1  [[879.50613649, 0, 629.72481947], [0.0, 879.50...
# 2  [[881.904049355, 0, 616.93208239], [0.0, 881.9...
# 3  [[3421.14214546, 0, 1003.11947364], [0.0, 3421...
# ...

# %%
with open("/home/vladimir/workspace/data2/lyft/kaggle/train_data/category.json") as f:
    df_category = pd.DataFrame(json.load(f))

# %%
df_category.head()
# Out:
#   description                                              token  \
# 0              8eccddb83fa7f8f992b2500f2ad658f65c9095588f3bc0...
# 1              73e8de69959eb9f5b4cd2859e74bec4b5491417336cad6...
# 2              f81f51e1897311b55c0c6247c3db825466733e08df687c...
# 3              a8619a81f5acc7da2a2f034420db2b2f43a015c8c68982...
# 4              7ea5868735dc408109bfa74fd139bd8c5aa3767b52e054...
#
#             name
# 0            car
# 1     pedestrian
# 2         animal
# 3  other_vehicle
# 4            bus

# %%
with open("/home/vladimir/workspace/data2/lyft/kaggle/train_data/ego_pose.json") as f:
    df_ego_pose = pd.DataFrame(json.load(f))

# %%
df_ego_pose.head()
# Out:
#                                             rotation  \
# 0  [0.8045437502844562, 0.02410792365998265, 0.01...
# 1  [-0.5929898606273702, -0.011481443936186955, 0...
# 2  [0.2796686043730183, 0.00271155518685425, 0.00...
# 3  [0.9635040845956131, 0.008858425028518862, -0....
# 4  [0.962480110281498, 0.01607462664369117, -0.00...
#
#                                          translation  \
# 0  [622.726103039258, 3460.3733051620957, -6.8134...
# 1  [422.73128659665366, 2823.226294125566, -18.25...
# 2  [1112.137330836936, 1671.8727689601853, -24.53...
# 3  [1558.7315956474536, 1367.4379093573166, -21.4...
# 4  [1840.7916379616522, 1198.6391492355403, -19.8...
#
#                                                token     timestamp
# 0  2de7c52546f3f9bf6734084da8a2c1edaa0ffbea7f6e86...  1.547166e+15
# 1  b270648672b4995af5aa80e34c8150897b17c9b96dc6b8...  1.548697e+15
# 2  c85d360434ae69600fa5918da32375335b3b3571be7c2b...  1.549920e+15
# ...

# %%
with open("/home/vladimir/workspace/data2/lyft/kaggle/train_data/instance.json") as f:
    df_instance = pd.DataFrame(json.load(f))

# %%
df_instance.head()
# Out:
#                                last_annotation_token  \
# 0  bcaa7c8be6503c2c2767b414e89598ea45ec1bf431eec1...
# 1  239d0037b395a24dc110529cbd4be98595d12cea75b396...
# 2  3c6fc88ad381df38877db77de1401d4cde2ac8ed1d8e88...
# 3  6a8ae9350f035f919c5ca2e56f5f5146bbf11fc7cd2e33...
# 4  804c82796713e93b4d52f3aeffceafef11acd9df2e4183...
#
#                                       category_token  \
# 0  8eccddb83fa7f8f992b2500f2ad658f65c9095588f3bc0...
# 1  8eccddb83fa7f8f992b2500f2ad658f65c9095588f3bc0...
# 2  8eccddb83fa7f8f992b2500f2ad658f65c9095588f3bc0...
# 3  8eccddb83fa7f8f992b2500f2ad658f65c9095588f3bc0...
# 4  8eccddb83fa7f8f992b2500f2ad658f65c9095588f3bc0...
#
#                                                token  \
# 0  c50ef1538e11e03d232eca295c80b0e76040507d4d2785...
# 1  a2629c325a79dce75fd81d84ef740f3ef2d5f1bce25e70...
# 2  570abc2fb67078ced6e96f7575c426db9128c98f05d161...
# 3  13d1f3b371fee6e5d48caf485d6cd77ee596a74cb65c10...
# ...

# %%
with open("/home/vladimir/workspace/data2/lyft/kaggle/train_data/log.json") as f:
    df_log = pd.DataFrame(json.load(f))

# %%
df_log.head()
# Out:
#   date_captured   location                                              token  \
# 0    2019-05-14  Palo Alto  da4ed9e02f64c544f4f1f10c6738216dcb0e6b0d50952e...
# 1    2019-03-07  Palo Alto  0a6839d6ee6804113bb5591ed99cc70ad883d0cff396e3...
# 2    2019-03-06  Palo Alto  a939e6edc494777d058c3b1eafb91a7236f6b4ff5e98c9...
# 3    2019-03-06  Palo Alto  e8f8379c823fd0505b63f2612505e1d3de1018ecc3328f...
# 4    2019-05-02  Palo Alto  ccc0662a4dbc63f589358ac9589b677f6d4165a128af93...
#
#   vehicle logfile
# 0    a101
# 1    a006
# 2    a011
# 3    a012
# 4    a101

# %%
with open("/home/vladimir/workspace/data2/lyft/kaggle/train_data/map.json") as f:
    df_map = pd.DataFrame(json.load(f))

# %%
df_map.head()
# Out:
#                                           log_tokens  \
# 0  [da4ed9e02f64c544f4f1f10c6738216dcb0e6b0d50952...
#
#                               token                       filename  \
# 0  53992ee3023e5494b90c316c183be829  maps/map_raster_palo_alto.png
#
#          category
# 0  semantic_prior

# %%
with open("/home/vladimir/workspace/data2/lyft/kaggle/train_data/sample.json") as f:
    df_sample = pd.DataFrame(json.load(f))

# %%
df_sample.head()
# Out:
#                                                 next  \
# 0  1d2350b3b20e3a5db2407e4075fc14f9f9ddfe0018f1da...
# 1  4f027d171715d57cd62079924e439f9ab17d228f27999a...
# 2  b66fb3c9a787cae35330b69f06cc18a7f06d0e61c7d06f...
# 3  063ea8386aa8156c1cd7c91bb1ac433f0b58d471e12658...
# 4  163666a4128b13159abd8ba202d9f0b05229507c27fc6b...
#
#                                                 prev  \
# 0  14511199ea101b40683cefafb9fcf5c2fb512fa500c3e6...
# 1  692caabc1f06aeda9f43d6252a070178430dec2158f19e...
# 2  0999dad89d3c95dd2976b4631b6deb3b3000e4de27afa3...
# 3  3222c742893edd007b982e9e7db40b7a598972d07bf759...
# 4
#
#                                                token     timestamp  \
# 0  b98a05255ba2632e957884758cb31f0e6fcc8d3cd6ee76...  1.552084e+15
# 1  78ce15b2b7360b8cd696d1097c60ec2184b69c17412564...  1.557855e+15
# 2  095d5bb88eb9cdd223b90d2a1475c0cf2f4b4c2a8aca82...  1.548780e+15
# 3  c2f0b2b2c0d576d42eab6e8703c4eacd302a79d4d702bd...  1.549481e+15
# ...

# %%
with open("/home/vladimir/workspace/data2/lyft/kaggle/train_data/sample_annotation.json") as f:
    df_sample_annotation = pd.DataFrame(json.load(f))

# %%
df_sample_annotation.head()
# Out:
#                                                token  num_lidar_pts  \
# 0  92bff46db1dbfc9679edc8091770c4256ac3c027e9f0a9...             -1
# 1  04c4c9883de582c5c4e7a45273a978a52b0432de18883f...             -1
# 2  4226ce1636193ced735e21ff3c6dcc292415c72d0f84b4...             -1
# 3  f2446d4ca4b3e79e982cf0a4134af12e71e7b59df42f42...             -1
# 4  1f5bdec4a1dff45dbbb4db094445dd4051eb39c9b4a2a3...             -1
#
#                     size                                       sample_token  \
# 0  [2.064, 5.488, 2.053]  db8b47bd4ebdf3b3fb21598bb41bd8853d12f8d2ef25ce...
# 1  [1.635, 4.339, 1.515]  edf37c1fb1024ba0c1f53ebbf10b6797f781199a9f0e4e...
# 2  [1.963, 4.345, 1.749]  1841b7895e7163a2c1be87e8c1740e759a910cd59157b8...
# 3     [2.2, 5.39, 2.187]  a970c764e7abd7ebc2cc4599a6e3ae58c9773ea3c9cf1d...
# 4  [1.837, 5.406, 1.721]  b909de93ba19460eeea58074ccc1ef6bb302435f37b48c...
#
#                                           rotation  \
# ...

# %%
with open("/home/vladimir/workspace/data2/lyft/kaggle/train_data/sample_data.json") as f:
    df_data = pd.DataFrame(json.load(f))

# %%
df_data.head()
# Out:
#    is_key_frame                                               prev fileformat  \
# 0          True  d190078ec7869ad5c9e5417371aa3b45eb1c22804a0a29...        bin
# 1          True  83f6f61cb6f2fc9b985cc23bd5613219eee7da390cd083...        bin
# 2          True  44555daed204fea486ec10ea1747432501b9f06fe93041...       jpeg
# 3          True  de75f3f347742035f2442f4a5fa0334946642daa2d07d8...       jpeg
# 4          True  a208568472ef6719faa2540622ada30b004583de9153f4...       jpeg
#
#                                                token     timestamp  \
# 0  ad87e1763749cc8562cca68e2046db128185c80c3e7599...  1.549921e+15
# 1  ea079138d89f3887b2bfcddfe16b747e2ec7a366ce66b3...  1.551742e+15
# 2  454c65ee6c297d64b17852b4c56def9781a84dcb8558a8...  1.550705e+15
# 3  779018e1f92debcf5c5c28e9577677c6595679780bdf9b...  1.546901e+15
# 4  d966960819eb0aca2883cd3c8d8c5e2540bda952a8cada...  1.549650e+15
#
#                                                 next  \
# ...

# %%
with open("/home/vladimir/workspace/data2/lyft/kaggle/train_data/scene.json") as f:
    df_scene = pd.DataFrame(json.load(f))

# %%
df_scene.head()
# Out:
#                                            log_token  \
# 0  da4ed9e02f64c544f4f1f10c6738216dcb0e6b0d50952e...
# 1  0a6839d6ee6804113bb5591ed99cc70ad883d0cff396e3...
# 2  a939e6edc494777d058c3b1eafb91a7236f6b4ff5e98c9...
# 3  e8f8379c823fd0505b63f2612505e1d3de1018ecc3328f...
# 4  ccc0662a4dbc63f589358ac9589b677f6d4165a128af93...
#
#                                   first_sample_token  \
# 0  24b0962e44420e6322de3f25d9e4e5cc3c7a348ec00bfa...
# 1  3b30673b9d944ec6058ef5a8debb4c0a6fe075bca7076e...
# 2  fcad797faa988f50be306e5fb6971de295602ee9116bd9...
# 3  8e1f13379721c1ab1d073607534ce7c195143cb8911715...
# 4  b6380a94d11315d22fd2313ae2e627ccb3579150cc9c67...
#
#                                                 name description  \
# 0  host-a101-lidar0-1241893239199111666-124189326...
# 1  host-a006-lidar0-1236037883198113706-123603790...
# 2  host-a011-lidar0-1235950297199142196-123595032...
# 3  host-a012-lidar0-1235937130198577346-123593715...
# ...

# %%
with open("/home/vladimir/workspace/data2/lyft/kaggle/train_data/sensor.json") as f:
    df_sensor = pd.DataFrame(json.load(f))

# %%
df_sensor.head(50)
# Out:
#   modality            channel  \
# 0   camera     CAM_FRONT_LEFT
# 1    lidar   LIDAR_FRONT_LEFT
# 2   camera          CAM_FRONT
# 3    lidar          LIDAR_TOP
# 4   camera      CAM_BACK_LEFT
# 5    lidar  LIDAR_FRONT_RIGHT
# 6   camera           CAM_BACK
# 7   camera     CAM_BACK_RIGHT
# 8   camera   CAM_FRONT_ZOOMED
# 9   camera    CAM_FRONT_RIGHT
#
#                                                token
# 0  f7dad6bb70cb8e6245f96e5537e382848335872e6e2592...
# 1  629da739ea3a0814b9d79ffc3b99cdbc8bdbb6f97abf13...
# 2  eb9e8f60a3d6e3328d7512b9f8e6800127fe91f4d62bc8...
# 3  25bf751d7e35f295393d8a418731474b21c1f702e878c4...
# 4  c84592e22beb2c0f14d5159245ce8d6678431b879e940e...
# 5  953faed96fd3d2fae3ec03cd2838b312b8c1a9bb7a0629...
# 6  172a55e2b50f18a6b6d545369a457003c2f3b438d0180b...
# 7  8e0259a868ddbfe589c2ce9c8bfb34a9e6c19c108b882c...
# 8  286718e1fbc8c8f0ca441969d91c36a8a809666e049e54...
# 9  de29f3ebb9d96988ac2c5913022c3102a51134e950284a...

# %%
with open("/home/vladimir/workspace/data2/lyft/kaggle/train_data/map.json") as f:
    df_map = pd.DataFrame(json.load(f))

# %%
df_map.head()
# Out:
#                                           log_tokens  \
# 0  [da4ed9e02f64c544f4f1f10c6738216dcb0e6b0d50952...
#
#                               token                       filename  \
# 0  53992ee3023e5494b90c316c183be829  maps/map_raster_palo_alto.png
#
#          category
# 0  semantic_prior

# %%
with open("/home/vladimir/workspace/data2/lyft/kaggle/train_data/visibility.json") as f:
    df_visibility = pd.DataFrame(json.load(f))

# %%
df_visibility.head()
# Out:
#      level                                        description token
# 0   v60-80   visibility of whole object is between 60 and 80%     3
# 1    v0-40    visibility of whole object is between 0 and 40%     1
# 2   v40-60   visibility of whole object is between 40 and 60%     2
# 3  v80-100  visibility of whole object is between 80 and 100%     4

# %%
df_scene['token'].nunique()
# Out:
# 180

# %%
with open("/home/vladimir/workspace/data2/lyft/kaggle/test_data/scene.json") as f:
    df_scene_test = pd.DataFrame(json.load(f))

# %%
df_scene_test["token"].nunique()
# Out:
# 218

# %%
180 + 218
# Out:
# 398

# %%
with open("/home/vladimir/workspace/data2/lyft/kaggle_solutions/solution.json") as f:
    df_gt_test = pd.DataFrame(json.load(f))

# %%
df_gt_test.shape
# Out:
# (780783, 5)

# %%
df_sample_annotation.shape
# Out:
# (638179, 12)

# %%
780783 + 638179
# Out:
# 1418962

# %%
df_sample['scene_token'].nunique()
# Out:
# 180

# %%
df_sample.head()
# Out:
#                                                 next  \
# 0  1d2350b3b20e3a5db2407e4075fc14f9f9ddfe0018f1da...
# 1  4f027d171715d57cd62079924e439f9ab17d228f27999a...
# 2  b66fb3c9a787cae35330b69f06cc18a7f06d0e61c7d06f...
# 3  063ea8386aa8156c1cd7c91bb1ac433f0b58d471e12658...
# 4  163666a4128b13159abd8ba202d9f0b05229507c27fc6b...
#
#                                                 prev  \
# 0  14511199ea101b40683cefafb9fcf5c2fb512fa500c3e6...
# 1  692caabc1f06aeda9f43d6252a070178430dec2158f19e...
# 2  0999dad89d3c95dd2976b4631b6deb3b3000e4de27afa3...
# 3  3222c742893edd007b982e9e7db40b7a598972d07bf759...
# 4
#
#                                                token     timestamp  \
# 0  b98a05255ba2632e957884758cb31f0e6fcc8d3cd6ee76...  1.552084e+15
# 1  78ce15b2b7360b8cd696d1097c60ec2184b69c17412564...  1.557855e+15
# 2  095d5bb88eb9cdd223b90d2a1475c0cf2f4b4c2a8aca82...  1.548780e+15
# 3  c2f0b2b2c0d576d42eab6e8703c4eacd302a79d4d702bd...  1.549481e+15
# ...

# %%
result = []

for scene_token, dft in df_sample.groupby("scene_token"):
    result += [dft['timestamp'].values]

# %%
np.diff(sorted(result[0]))
# Out:
# array([200108.25, 200341.75, 200302.25, 199890.25, 199583.5 , 199606.25,
#        199810.75, 199940.25, 200095.25, 200250.5 , 200346.25, 200261.75,
#        199827.25, 199489.25, 199406.5 , 199529.25, 199742.75, 199920.25,
#        200105.25, 200311.5 , 200431.25, 200454.75, 200193.25, 199923.25,
#        199938.5 , 200033.25, 200216.75, 200285.25, 200252.25, 199945.5 ,
#        199596.25, 199534.75, 199670.25, 199907.25, 200082.5 , 200180.25,
#        200337.75, 200226.25, 199883.25, 199731.5 , 199740.25, 199877.75,
#        200011.25, 200220.25, 200307.5 , 199944.25, 199667.75, 199733.25,
#        199922.25, 200105.5 , 200260.25, 200425.75, 200411.25, 200169.25,
#        199767.5 , 199398.25, 199374.75, 199538.25, 199799.25, 200091.5 ,
#        200237.25, 200387.75, 200409.25, 200288.25, 200136.5 , 200038.25,
#        200193.75, 200282.25, 200202.25, 199877.5 , 199566.25, 199531.75,
#        199666.25, 199881.25, 200059.5 , 200173.25, 200371.75, 200386.25,
# ...

# %%
np.diff(sorted(result[1]))
# Out:
# array([200156.5 , 200088.25, 200202.75, 200252.25, 200104.25, 199735.5 ,
#        199444.25, 199427.75, 199554.25, 199825.25, 200151.5 , 200225.25,
#        200282.75, 200372.25, 200453.25, 200201.5 , 199763.25, 199640.75,
#        199717.25, 199922.25, 200164.5 , 200237.25, 200220.75, 199995.25,
#        199917.25, 200104.5 , 200170.25, 200197.75, 199978.25, 199723.25,
#        199750.5 , 199895.25, 200016.75, 200129.25, 200226.25, 200316.5 ,
#        200224.25, 199916.75, 199623.25, 199641.25, 199804.5 , 199952.25,
#        200140.75, 200195.25, 200233.25, 200226.5 , 200052.25, 199805.75,
#        199679.25, 199804.25, 200020.5 , 200164.25, 200269.75, 200181.25,
#        199970.25, 199650.5 , 199510.25, 199663.75, 199805.25, 200037.25,
#        200309.5 , 200431.25, 200326.75, 199981.25, 199828.25, 199929.5 ,
#        200061.25, 200264.75, 200388.25, 200159.25, 199649.5 , 199424.25,
#        199565.75, 199807.25, 200077.25, 200274.5 , 200266.25, 200055.75,
# ...

# %%
result[0][0]
# Out:
# 1551831523001937.5
